# %% [markdown]
# 1.Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("youtube_dislike_dataset.csv")
df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# 2.Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.shape
# Out:
# (37422, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [raw]
# Here are some inferences regarding the data types and shape of the data set.
#
# The dataset has 37,422 rows (entries) and 12 columns.
# The data type in the dataset include:
#
# object: video_id,title,channel_id,channel_title,published_at,tags,description,comments.
#
# int64:likes,dislikes,view_count,comment_count.
#
# There are some missing values in the comments column, with 37264 non-null entries out of the total 37422.
# The Categorial columns are:
#
# video_id,title,channel_id,channel_title,view_count,tags,description,comments.
# The numericals columns are:
#
# likes,dislikes,view_count,comment_count.
# The published_at column contains timestamp information, but it is currently stored as an object.

# %% [markdown]
# 3. Check for the Percentage of the missing values and drop or impute them.

# %%
(df.isnull().sum()*100)/len(df)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
df['comments'].fillna(value="Missing",inplace=True)

# %%
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [raw]
# There was 0.42% of missing values in comments column.

# %% [markdown]
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [raw]
# Video Popularity:
# Most videos have a moderate number of views, with an average of around 5.7 million.
# Some videos, though, are extremely popular, with the highest having over 1.32 billion views.
#
# Likes and Dislikes:
# On average, videos receive about 166,800 likes and 4,990 dislikes.
# The majority of videos have a reasonable number of likes, while dislikes are generally lower than likes.
#
# Comments:
# Videos receive an average of around 9,925 comments.
# Most videos get a moderate number of comments, with a few highly commented ones.
#
# Engagement Levels:
# Engagement levels, as measured by likes and comments, are generally positive, indicating viewer interaction with the content.
#
# Outliers:
# Some videos stand out as outliers with exceptionally high views, likes, or comments, significantly influencing the average value

# %%
df.select_dtypes(include='object').describe()
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description comments
# count                 37422  37422       37422    37422
# unique                36772  28799       35630    37265
# top     2020-10-16 04:00:10                     Missing
# freq                      6   3817         589      158

# %% [raw]
# Diverse Videos:
# There are 37,422 unique videos, each identified by a distinct video ID.
#
# Title Variation:
# While there are 37,422 records, there are only 37,113 unique titles, indicating some videos share the same title.
#
# Channel Insights:
# There are 10,961 unique channels, suggesting a variety of content creators.
# Some channels have multiple videos, as indicated by the difference in unique channel IDs and titles.
#
# Popular Publishing Date:
# The most common publishing date is 2020-10-16, occurring 6 times. Further exploration can reveal if this date is significant or coincidental.
#
# Tag Diversity:
# There is a wide variety of 36,772 unique tags, showcasing the diversity in how videos are categorized.
#
# Description Gaps:
# The most frequent description is empty or contains whitespace in 3,817 records. Considering these gaps may be important for understanding viewer interaction and searchability.
#
# Comments Availability:
# Comments are available for 37,264 videos, but 158 videos have missing comment data. Investigating the missing comments could provide insights into user engagement.
#
# Further Exploration Opportunities:
# Analyzing the distribution of published dates and exploring relationships between channel titles and IDs could reveal patterns in content creation.
# Handling missing data in descriptions may enhance the understanding of video content.

# %% [markdown]
# 5. Convert datatype of column published_at from object to pandas datetime.

# %%
df['published_at']=pd.to_datetime(df['published_at'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  datetime64[ns]
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.4+ MB

# %% [markdown]
# 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month']=df['published_at'].dt.month
df['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37422, dtype: int32

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
df['published_month']=df['published_at'].dt.month_name()
df['published_month']
# Out:
# 0             July
# 1             June
# 2        September
# 3            March
# 4         December
#            ...
# 37417     February
# 37418      January
# 37419         June
# 37420      October
# 37421          May
# Name: published_month, Length: 37422, dtype: object

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
pd.pivot_table(data=df,values='video_id',index='published_month',aggfunc='count').sort_values(by='video_id',ascending=False)
# Out:
#                  video_id
# published_month
# October              4991
# September            4880
# November             4851
# August               4262
# December             3072
# July                 2340
# June                 2316
# March                2258
# February             2137
# April                2126
# January              2108
# May                  2081

# %% [markdown]
# 9. Find the count of unique video_id, channel_id and channel_title.

# %%
print("count of unique video_id:",df['video_id'].nunique())
# Out:
# count of unique video_id: 37422

# %%
print("count of unique  channel_id :",df['channel_id'].nunique())
# Out:
# count of unique  channel_id : 10961

# %%
print("count of unique  channel_title:",df['channel_title'].nunique())
# Out:
# count of unique  channel_title: 10883

# %% [markdown]
# 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
channel=pd.DataFrame(df.groupby(by='channel_title')['video_id'].count()).sort_values(by='video_id',ascending=False)
channel.head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
channel.tail(10)
# Out:
#                 video_id
# channel_title
# Karchez                1
# Karate Combat          1
# Kaptain Kuba           1
# Kanye West             1
# Kannur kitchen         1
# Kannada Cinema         1
# KanalD                 1
# Kanak News             1
# Kamille Ramos          1
# zoom                   1

# %% [markdown]
# 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
likes=pd.DataFrame(df.groupby(by='title')['likes'].max()).sort_values(by='likes',ascending=False)
likes.head(5)
# Out:
#                                                     likes
# title
# BTS () 'Dynamite' Official MV                    31837675
# BTS () 'Butter' Official MV                      20649409
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V  17864527
# BTS () 'Life Goes On' Official MV                16354127
# BTS () 'Permission to Dance' Official MV         15449003

# %% [raw]
# BTS Dominance:
# BTS videos, especially "Dynamite" and "Butter," lead in likes, showcasing their widespread popularity.
#
# BLACKPINK's Impact:
# BLACKPINK's "Ice Cream" with Selena Gomez also stands out with a significant number of likes.
#
# Viewer Preferences:
# Different videos attract varying levels of likes, indicating diverse viewer preferences.
#
# Trend Analysis Potential:
# Examining likes over time can reveal trends, helping anticipate future video performance.
#
# Correlation Exploration:
# Exploring connections between video popularity and factors like release dates or promotional efforts can provide valuable insights for content strategies.

# %%
likes.tail(5).sort_values(by='likes',ascending=True)
# Out:
#                                                     likes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...      0
# Leading the Charge | Circle K                          22
# Tims For Good: A Taste Of The Familiar                 28
# Small Business Loans from OnDeck                       29
# Virtual Pub Quiz, Live! Saturday 12th December         97

# %% [raw]
# The title "Kim Kardashian's Must-See Moments on 'Saturday Night Live'" received zero likes, suggesting that this content may not have resonated well with viewers or that likes might be disabled for this particular video.

# %% [markdown]
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
dislikes=pd.DataFrame(df.groupby(by='title')['dislikes'].max()).sort_values(by='dislikes',ascending=False)
dislikes.head(5)
# Out:
#                                                     dislikes
# title
# Cuties | Official Trailer | Netflix                  2397733
# BTS () 'Dynamite' Official MV                        1814333
# Cardi B - WAP feat. Megan Thee Stallion [Offici...   1331181
# 52 GAJ KA DAMAN | PRANJAL DAHIYA | AMAN JAJI | ...   1259533
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V      1253187

# %% [raw]
# Controversial Content:
# The trailer for "Cuties" on Netflix has the highest number of dislikes, suggesting that it may be a controversial or divisive piece of content.
#
# BTS Impact:
# BTS's "Dynamite" has a substantial number of dislikes, showcasing that even popular content can receive criticism or negative feedback.
#
# Cardi B's "WAP":
# Cardi B's "WAP" music video also received a notable number of dislikes, indicating that the content may have sparked mixed reactions.
#
# Regional Flavor:
# "52 GAJ KA DAMAN" by Pranjal Dahiya has a significant number of dislikes, possibly reflecting diverse audience opinions on regional content.
#
# BLACKPINK's Reception:
# BLACKPINK's "Ice Cream (with Selena Gomez)" received dislikes, suggesting that even videos from popular artists may not be universally liked.

# %%
dislikes.tail(5).sort_values(by='dislikes',ascending=True)
# Out:
#                                                     dislikes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...         0
# Tims For Good: A Taste Of The Familiar                     3
# Live Stream: Hampshire v Yorkshire - LV= County...         4
# Leeds Rhinos vs Wakefield Trinity | Super Leagu...         6
# Virtual Pub Quiz, Live Saturday 24th October               7

# %% [raw]
# Minimal Dislikes:
# "Kim Kardashian's Must-See Moments on 'Saturday Night Live'" and "Tims For Good: A Taste Of The Familiar" have zero and three dislikes, respectively, indicating a low level of negative feedback.
#
# Sports and Live Content:
# Titles related to sports events, such as "Live Stream: Hampshire v Yorkshire" and "Leeds Rhinos vs Wakefield Trinity," as well as a live quiz ("Virtual Pub Quiz"), have a small number of dislikes. This suggests a generally positive reception or minimal controversy.
#
# Interactive Content:
# "Virtual Pub Quiz, Live Saturday 24th October" has a slightly higher dislike count, possibly indicating some mixed reactions to interactive or live content.
#
# Limited Negative Feedback:
# Overall, the dislikes for these titles are relatively low, suggesting that the content may not be highly controversial or dislikedviewer sentiment.

# %% [markdown]
# 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
import seaborn as sns
df.select_dtypes(include='int64').corr()
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.784229  0.684469       0.464392
# likes            0.784229  1.000000  0.679817       0.580953
# dislikes         0.684469  0.679817  1.000000       0.391739
# comment_count    0.464392  0.580953  0.391739       1.000000

# %%
df['view_count'].corr(df['dislikes'])
# Out:
# 0.6844687753905547

# %%
sns.scatterplot(x=df['view_count'],y=df['dislikes'])
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
correlation_matrix =df.select_dtypes(include='number').corr()
correlation_matrix
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.784229  0.684469       0.464392
# likes            0.784229  1.000000  0.679817       0.580953
# dislikes         0.684469  0.679817  1.000000       0.391739
# comment_count    0.464392  0.580953  0.391739       1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January

# %%
df['published_month'].unique()
# Out:
# array(['July', 'June', 'September', 'March', 'December', 'October',
#        'August', 'April', 'May', 'November', 'February', 'January'],
#       dtype=object)

# %%
required_data = df.groupby('published_month')
january_data = required_data.get_group('January')
january_data
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
january_data['video_id'].count()
# Out:
# 2108
